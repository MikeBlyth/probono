# %%
# Import pandas and sqlalchemy -- for setup one time
try:
    import pandas as pd
    import sqlalchemy
    from dotenv import load_dotenv
    print(f"Vibe Check Passed: Pandas {pd.__version__} is ready!")
except ImportError:
    print("Pantry is empty. Stocking shelves now...")
    # !pip install pandas sqlalchemy psycopg2-binary pgvector google-generativeai python-dotenv
    print("Installation complete! Please go to 'Kernel' -> 'Restart Kernel' above.")
